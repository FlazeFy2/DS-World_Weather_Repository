# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("GlobalWeatherRepository.csv")

# Data Understanding - Variable & Data Type
print(df.dtypes)
print("\n")
print(f"{len(df.columns)} Column")
 
# Data Preparation - Handle Missing Value
df.isnull().sum()

# Data Preparation - Invalid Numeric Column
ratio_column = [
    'latitude', 'longitude', 'temperature_celsius', 'temperature_fahrenheit',
    'wind_mph', 'wind_kph', 'wind_degree', 'pressure_mb', 'pressure_in',
    'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
    'feels_like_fahrenheit', 'visibility_km', 'visibility_miles', 'uv_index',
    'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
    'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
    'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
    'air_quality_gb-defra-index', 'moon_illumination'
]
for dt in ratio_column:
    plt.boxplot(df[dt])
    plt.title(f'Boxplot of {dt}')
    plt.show()
    
    invalid = df[df[dt] < 0]
    print(invalid.index)
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                     float64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %%
# Data Preparation - Numerical Statistic
print(df.describe())
# Out:
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  63923.000000  63923.000000        6.392300e+04         63923.000000
# mean      19.134507     22.177801        1.730093e+09            22.095557
# std       24.474604     65.820931        8.249868e+06             9.588942
# min      -41.300000   -175.200000        1.715849e+09           -24.900000
# 25%        3.750000     -6.836100        1.723032e+09            16.400000
# 50%       17.250000     23.316700        1.730107e+09            24.900000
# 75%       40.400000     50.580000        1.737278e+09            28.400000
# max       64.150000    179.220000        1.744277e+09            49.200000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            63923.000000  63923.000000  63923.000000  63923.000000
# mean                71.773629      8.293355     13.350728    168.662938
# std                 17.259878      9.039372     14.545589    103.807283
# ...
