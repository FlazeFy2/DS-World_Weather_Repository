# %%
import pandas as pd
import statistics
import numpy as np

# Declaration
data = pd.read_csv("GlobalWeatherRepository.csv")

target_col = ["latitude", "longitude", "last_updated_epoch", "temperature_celsius", "temperature_fahrenheit", "wind_mph", "wind_kph", "wind_degree", "pressure_mb", "pressure_in", "precip_mm", "precip_in", "humidity", "cloud", "feels_like_celsius", "feels_like_fahrenheit", "visibility_km", "visibility_miles", "uv_index", "gust_mph", "gust_kph", "air_quality_Carbon_Monoxide", "air_quality_Ozone", "air_quality_Nitrogen_dioxide", "air_quality_Sulphur_dioxide", "air_quality_PM2.5", "air_quality_PM10", "air_quality_us-epa-index", "air_quality_gb-defra-index", "moon_illumination"]

for dt in target_col:
    # Convert to int
    data[dt] = pd.to_numeric(data[dt], errors='coerce')
    
    # Remove NaN
    data = data.dropna(subset=[dt])

    max_val = data[dt].max()
    min_val = data[dt].min()
    range_val = max_val - min_val
    mean = round(data[dt].mean(),2)
    mode = round(statistics.mode(data[dt]),2)
    var = round(np.nanvar(data[dt],ddof=1),2)
    std = round(var ** 0.5,2)

    print(f"Max of {dt.title()} : {max_val}")
    print(f"Min of {dt.title()} : {min_val}")
    print(f"Range of {dt.title()} : {range_val}")
    print(f"Mean of {dt.title()} : {mean}")
    print(f"Mode of {dt.title()} : {mode}")
    print(f"Variance of {dt.title()} : {var}")
    print(f"Standard Deviance of {dt.title()} : {std}\n")
# Out:
# Max of Latitude : 64.15
# Min of Latitude : -41.3
# Range of Latitude : 105.45
# Mean of Latitude : 19.13
# Mode of Latitude : 41.9
# Variance of Latitude : 599.01
# Standard Deviance of Latitude : 24.47
#
# Max of Longitude : 179.22
# Min of Longitude : -175.2
# Range of Longitude : 354.41999999999996
# Mean of Longitude : 22.18
# Mode of Longitude : 12.45
# Variance of Longitude : 4332.39
# Standard Deviance of Longitude : 65.82
#
# Max of Last_Updated_Epoch : 1744277400
# Min of Last_Updated_Epoch : 1715849100
# Range of Last_Updated_Epoch : 28428300
# Mean of Last_Updated_Epoch : 1730093141.05
# Mode of Last_Updated_Epoch : 1715849100
# Variance of Last_Updated_Epoch : 68060319813381.11
# Standard Deviance of Last_Updated_Epoch : 8249867.87
#
# Max of Temperature_Celsius : 49.2
# Min of Temperature_Celsius : -24.9
# Range of Temperature_Celsius : 74.1
# Mean of Temperature_Celsius : 22.1
# Mode of Temperature_Celsius : 28.2
# Variance of Temperature_Celsius : 91.95
# Standard Deviance of Temperature_Celsius : 9.59
#
# Max of Temperature_Fahrenheit : 120.6
# Min of Temperature_Fahrenheit : -12.8
# Range of Temperature_Fahrenheit : 133.4
# Mean of Temperature_Fahrenheit : 71.77
# Mode of Temperature_Fahrenheit : 82.8
# Variance of Temperature_Fahrenheit : 297.9
# Standard Deviance of Temperature_Fahrenheit : 17.26
#
# Max of Wind_Mph : 1841.2
# Min of Wind_Mph : 2.2
# Range of Wind_Mph : 1839.0
# Mean of Wind_Mph : 8.29
# Mode of Wind_Mph : 2.2
# Variance of Wind_Mph : 81.71
# Standard Deviance of Wind_Mph : 9.04
#
# Max of Wind_Kph : 2963.2
# Min of Wind_Kph : 3.6
# Range of Wind_Kph : 2959.6
# Mean of Wind_Kph : 13.35
# Mode of Wind_Kph : 3.6
# Variance of Wind_Kph : 211.57
# Standard Deviance of Wind_Kph : 14.55
#
# Max of Wind_Degree : 360
# Min of Wind_Degree : 1
# Range of Wind_Degree : 359
# Mean of Wind_Degree : 168.66
# Mode of Wind_Degree : 10
# Variance of Wind_Degree : 10775.95
# Standard Deviance of Wind_Degree : 103.81
#
# Max of Pressure_Mb : 3006.0
# Min of Pressure_Mb : 947.0
# Range of Pressure_Mb : 2059.0
# Mean of Pressure_Mb : 1014.17
# Mode of Pressure_Mb : 1013.0
# Variance of Pressure_Mb : 174.62
# Standard Deviance of Pressure_Mb : 13.21
#
# Max of Pressure_In : 88.77
# Min of Pressure_In : 27.96
# Range of Pressure_In : 60.809999999999995
# Mean of Pressure_In : 29.95
# Mode of Pressure_In : 29.88
# Variance of Pressure_In : 0.15
# Standard Deviance of Pressure_In : 0.39
#
# Max of Precip_Mm : 42.24
# Min of Precip_Mm : 0.0
# Range of Precip_Mm : 42.24
# Mean of Precip_Mm : 0.14
# Mode of Precip_Mm : 0.0
# Variance of Precip_Mm : 0.37
# Standard Deviance of Precip_Mm : 0.61
#
# Max of Precip_In : 1.66
# Min of Precip_In : 0.0
# Range of Precip_In : 1.66
# Mean of Precip_In : 0.01
# Mode of Precip_In : 0.0
# Variance of Precip_In : 0.0
# Standard Deviance of Precip_In : 0.0
#
# Max of Humidity : 100
# Min of Humidity : 2
# Range of Humidity : 98
# Mean of Humidity : 63.63
# Mode of Humidity : 94
# Variance of Humidity : 595.36
# Standard Deviance of Humidity : 24.4
#
# Max of Cloud : 100
# Min of Cloud : 0
# Range of Cloud : 100
# Mean of Cloud : 40.11
# Mode of Cloud : 0
# Variance of Cloud : 1151.06
# Standard Deviance of Cloud : 33.93
#
# Max of Feels_Like_Celsius : 51.2
# Min of Feels_Like_Celsius : -35.6
# Range of Feels_Like_Celsius : 86.80000000000001
# Mean of Feels_Like_Celsius : 22.99
# Mode of Feels_Like_Celsius : 24.6
# Variance of Feels_Like_Celsius : 130.3
# Standard Deviance of Feels_Like_Celsius : 11.41
#
# Max of Feels_Like_Fahrenheit : 124.2
# Min of Feels_Like_Fahrenheit : -32.1
# Range of Feels_Like_Fahrenheit : 156.3
# Mean of Feels_Like_Fahrenheit : 73.38
# Mode of Feels_Like_Fahrenheit : 76.2
# Variance of Feels_Like_Fahrenheit : 422.1
# Standard Deviance of Feels_Like_Fahrenheit : 20.55
#
# Max of Visibility_Km : 32.0
# Min of Visibility_Km : 0.0
# Range of Visibility_Km : 32.0
# Mean of Visibility_Km : 9.59
# Mode of Visibility_Km : 10.0
# Variance of Visibility_Km : 6.41
# Standard Deviance of Visibility_Km : 2.53
#
# Max of Visibility_Miles : 19.0
# Min of Visibility_Miles : 0.0
# Range of Visibility_Miles : 19.0
# Mean of Visibility_Miles : 5.68
# Mode of Visibility_Miles : 6.0
# Variance of Visibility_Miles : 2.48
# Standard Deviance of Visibility_Miles : 1.57
#
# Max of Uv_Index : 16.3
# Min of Uv_Index : 0.0
# Range of Uv_Index : 16.3
# Mean of Uv_Index : 4.01
# Mode of Uv_Index : 0.0
# Variance of Uv_Index : 13.11
# Standard Deviance of Uv_Index : 3.62
#
# Max of Gust_Mph : 1845.7
# Min of Gust_Mph : 2.2
# Range of Gust_Mph : 1843.5
# Mean of Gust_Mph : 11.84
# Mode of Gust_Mph : 6.7
# Variance of Gust_Mph : 104.2
# Standard Deviance of Gust_Mph : 10.21
#
# Max of Gust_Kph : 2970.4
# Min of Gust_Kph : 3.6
# Range of Gust_Kph : 2966.8
# Mean of Gust_Kph : 19.06
# Mode of Gust_Kph : 10.8
# Variance of Gust_Kph : 269.89
# Standard Deviance of Gust_Kph : 16.43
#
# Max of Air_Quality_Carbon_Monoxide : 38879.398
# Min of Air_Quality_Carbon_Monoxide : -9999.0
# Range of Air_Quality_Carbon_Monoxide : 48878.398
# Mean of Air_Quality_Carbon_Monoxide : 528.66
# Mode of Air_Quality_Carbon_Monoxide : 217.0
# Variance of Air_Quality_Carbon_Monoxide : 855758.61
# Standard Deviance of Air_Quality_Carbon_Monoxide : 925.07
#
# Max of Air_Quality_Ozone : 480.7
# Min of Air_Quality_Ozone : 0.0
# Range of Air_Quality_Ozone : 480.7
# Mean of Air_Quality_Ozone : 63.73
# Mode of Air_Quality_Ozone : 68.0
# Variance of Air_Quality_Ozone : 1275.23
# Standard Deviance of Air_Quality_Ozone : 35.71
#
# Max of Air_Quality_Nitrogen_Dioxide : 427.7
# Min of Air_Quality_Nitrogen_Dioxide : 0.0
# Range of Air_Quality_Nitrogen_Dioxide : 427.7
# Mean of Air_Quality_Nitrogen_Dioxide : 15.25
# Mode of Air_Quality_Nitrogen_Dioxide : 0.0
# Variance of Air_Quality_Nitrogen_Dioxide : 694.34
# Standard Deviance of Air_Quality_Nitrogen_Dioxide : 26.35
#
# Max of Air_Quality_Sulphur_Dioxide : 521.33
# Min of Air_Quality_Sulphur_Dioxide : -9999.0
# Range of Air_Quality_Sulphur_Dioxide : 10520.33
# Mean of Air_Quality_Sulphur_Dioxide : 11.44
# Mode of Air_Quality_Sulphur_Dioxide : 0.1
# Variance of Air_Quality_Sulphur_Dioxide : 2256.42
# Standard Deviance of Air_Quality_Sulphur_Dioxide : 47.5
#
# Max of Air_Quality_Pm2.5 : 1614.1
# Min of Air_Quality_Pm2.5 : 0.185
# Range of Air_Quality_Pm2.5 : 1613.915
# Mean of Air_Quality_Pm2.5 : 25.76
# Mode of Air_Quality_Pm2.5 : 0.5
# Variance of Air_Quality_Pm2.5 : 1939.71
# Standard Deviance of Air_Quality_Pm2.5 : 44.04
#
# Max of Air_Quality_Pm10 : 6037.29
# Min of Air_Quality_Pm10 : -1848.15
# Range of Air_Quality_Pm10 : 7885.4400000000005
# Mean of Air_Quality_Pm10 : 52.21
# Mode of Air_Quality_Pm10 : 0.6
# Variance of Air_Quality_Pm10 : 25881.76
# Standard Deviance of Air_Quality_Pm10 : 160.88
#
# Max of Air_Quality_Us-Epa-Index : 6
# Min of Air_Quality_Us-Epa-Index : 1
# Range of Air_Quality_Us-Epa-Index : 5
# Mean of Air_Quality_Us-Epa-Index : 1.74
# Mode of Air_Quality_Us-Epa-Index : 1
# Variance of Air_Quality_Us-Epa-Index : 0.99
# Standard Deviance of Air_Quality_Us-Epa-Index : 0.99
#
# Max of Air_Quality_Gb-Defra-Index : 10
# Min of Air_Quality_Gb-Defra-Index : 1
# Range of Air_Quality_Gb-Defra-Index : 9
# Mean of Air_Quality_Gb-Defra-Index : 2.74
# Mode of Air_Quality_Gb-Defra-Index : 1
# Variance of Air_Quality_Gb-Defra-Index : 6.78
# Standard Deviance of Air_Quality_Gb-Defra-Index : 2.6
#
# Max of Moon_Illumination : 100
# Min of Moon_Illumination : 0
# Range of Moon_Illumination : 100
# Mean of Moon_Illumination : 49.29
# Mode of Moon_Illumination : 0
# Variance of Moon_Illumination : 1217.53
# Standard Deviance of Moon_Illumination : 34.89

# %%
import pandas as pd
import statistics
import numpy as np

# Display settings
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.width', 0)

# Descriptive Statistic : Show Region Average Temp, Wind Speed, Humid, Air Quality, and UV Index
data = pd.read_csv("GlobalWeatherRepository.csv")

# Define Region from first string index after split "/"
data['region'] = data['timezone'].str.split('/').str[0]

# Group By Context and Average
region_data = data.groupby('region')[['temperature_celsius','wind_kph','humidity','air_quality_PM2.5','uv_index']].mean().round(2)
region_data = region_data.rename(columns={
    'temperature_celsius': 'Average Temp in C°',
    'wind_kph': 'Average Wind Speed (Kmh)',
    'humidity': 'Humid',
    'air_quality_PM2.5': 'Air Quality PM2.5',
    'uv_index': 'UV Index'
})

print(region_data)
# Out:
#            Average Temp in C°  Average Wind Speed (Kmh)  Humid  Air Quality PM2.5  UV Index
# region
# Africa                  27.05                     13.95  53.60              27.31      7.11
# America                 21.27                     11.25  82.48              20.35      2.24
# Asia                    23.77                     12.50  52.84              42.49      3.56
# Atlantic                15.48                     25.83  75.17              15.35      2.39
# Australia               12.81                     10.84  74.65               6.93      0.46
# Europe                  15.10                     13.36  64.21              18.87      3.28
# Indian                  27.48                     16.25  62.96               8.85      8.57
# Pacific                 25.30                     17.20  85.01               7.05      0.46
